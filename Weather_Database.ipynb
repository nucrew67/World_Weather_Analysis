# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs = [pair for pair in zip(lats, lngs)]
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import config from another folder
import sys
sys.path.append('../')

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | vyshchetarasivka
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | mnogovershinnyy
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | lewistown
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | tongliao
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | acarau
# Processing Record 19 of Set 1 | ust-koksa
# Processing Record 20 of Set 1 | coolum beach
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | camacha
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | cabo san lucas
# Processing Record 28 of Set 1 | laguna
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 1 | frankfurt
# Processing Record 32 of Set 1 | bonthe
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | virginia beach
# Processing Record 36 of Set 1 | half moon bay
# Processing Record 37 of Set 1 | betanzos
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | achacachi
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | shimoda
# Processing Record 45 of Set 1 | pervoye maya
# Processing Record 46 of Set 1 | paamiut
# Processing Record 47 of Set 1 | tahe
# Processing Record 48 of Set 1 | mocuba
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | mgandu
# Processing Record 4 of Set 2 | aksarka
# Processing Record 5 of Set 2 | lerwick
# Processing Record 6 of Set 2 | kiruna
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | tual
# Processing Record 9 of Set 2 | charters towers
# Processing Record 10 of Set 2 | posse
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | mahebourg
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | bambanglipuro
# Processing Record 19 of Set 2 | carndonagh
# Processing Record 20 of Set 2 | ocara
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | kudahuvadhoo
# Processing Record 23 of Set 2 | crixas
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 2 | port hedland
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | berlevag
# Processing Record 29 of Set 2 | shingu
# Processing Record 30 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 2 | alwar
# Processing Record 32 of Set 2 | singaraja
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | maceio
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | campbell river
# Processing Record 37 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 2 | puerto colombia
# Processing Record 39 of Set 2 | pangody
# Processing Record 40 of Set 2 | grand gaube
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | ahipara
# Processing Record 44 of Set 2 | cherlak
# Processing Record 45 of Set 2 | pacific grove
# Processing Record 46 of Set 2 | pahrump
# Processing Record 47 of Set 2 | srednekolymsk
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | lumeje
# Processing Record 4 of Set 3 | north bend
# Processing Record 5 of Set 3 | srandakan
# Processing Record 6 of Set 3 | casablanca
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | dunda
# Processing Record 9 of Set 3 | nuuk
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | uvira
# Processing Record 12 of Set 3 | teknaf
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | thinadhoo
# Processing Record 15 of Set 3 | san vicente
# Processing Record 16 of Set 3 | sisimiut
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | marquette
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | hearst
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | arlit
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | shakawe
# Processing Record 27 of Set 3 | campanha
# Processing Record 28 of Set 3 | gravdal
# Processing Record 29 of Set 3 | vila velha
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | coahuayana
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | belaya gora
# Processing Record 35 of Set 3 | anupgarh
# Processing Record 36 of Set 3 | ubala
# Processing Record 37 of Set 3 | emerald
# Processing Record 38 of Set 3 | ust-maya
# Processing Record 39 of Set 3 | beira
# Processing Record 40 of Set 3 | vestmanna
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | bianzhuang
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | ilhabela
# Processing Record 45 of Set 3 | chota
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | tsaratanana
# Processing Record 50 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | sinnamary
# Processing Record 2 of Set 4 | kirgiz-miyaki
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | samarai
# Processing Record 5 of Set 4 | bafoulabe
# Processing Record 6 of Set 4 | gbarnga
# Processing Record 7 of Set 4 | san pedro de macoris
# Processing Record 8 of Set 4 | kalabo
# Processing Record 9 of Set 4 | ixtapa
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | bilibino
# Processing Record 13 of Set 4 | palmeirais
# Processing Record 14 of Set 4 | libenge
# Processing Record 15 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 4 | pangnirtung
# Processing Record 17 of Set 4 | muli
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | nikolayevsk-na-amure
# Processing Record 20 of Set 4 | tura
# Processing Record 21 of Set 4 | guerrero negro
# Processing Record 22 of Set 4 | nijar
# Processing Record 23 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 4 | mayumba
# Processing Record 25 of Set 4 | andenes
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 28 of Set 4 | atar
# Processing Record 29 of Set 4 | provideniya
# Processing Record 30 of Set 4 | walsrode
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | sorong
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | tabuk
# Processing Record 35 of Set 4 | roald
# Processing Record 36 of Set 4 | olafsvik
# Processing Record 37 of Set 4 | paita
# Processing Record 38 of Set 4 | necochea
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | kajaani
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | sangar
# Processing Record 48 of Set 4 | kushiro
# Processing Record 49 of Set 4 | naguabo
# Processing Record 50 of Set 4 | axim
# Processing Record 1 of Set 5 | boralday
# Processing Record 2 of Set 5 | baykit
# Processing Record 3 of Set 5 | karratha
# Processing Record 4 of Set 5 | atasu
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | maniitsoq
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | dothan
# Processing Record 13 of Set 5 | barrow
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | ipora
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | tatawin
# Processing Record 18 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | meulaboh
# Processing Record 21 of Set 5 | chicama
# Processing Record 22 of Set 5 | varna
# Processing Record 23 of Set 5 | mabaruma
# Processing Record 24 of Set 5 | tuzha
# Processing Record 25 of Set 5 | christchurch
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | nabul
# City not found. Skipping...
# Processing Record 29 of Set 5 | neiafu
# Processing Record 30 of Set 5 | portland
# Processing Record 31 of Set 5 | sabang
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | kasama
# Processing Record 34 of Set 5 | tabory
# Processing Record 35 of Set 5 | prnjavor
# Processing Record 36 of Set 5 | teya
# Processing Record 37 of Set 5 | isangel
# Processing Record 38 of Set 5 | koumac
# Processing Record 39 of Set 5 | havoysund
# Processing Record 40 of Set 5 | the valley
# Processing Record 41 of Set 5 | maldonado
# Processing Record 42 of Set 5 | itaituba
# Processing Record 43 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 44 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 5 | stornoway
# Processing Record 46 of Set 5 | qaanaaq
# Processing Record 47 of Set 5 | noumea
# Processing Record 48 of Set 5 | phalombe
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | casillas
# Processing Record 1 of Set 6 | huntington
# Processing Record 2 of Set 6 | sahuaripa
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | riyadh
# Processing Record 5 of Set 6 | boo
# Processing Record 6 of Set 6 | yumen
# Processing Record 7 of Set 6 | mehamn
# Processing Record 8 of Set 6 | vao
# Processing Record 9 of Set 6 | terrace
# Processing Record 10 of Set 6 | chifeng
# Processing Record 11 of Set 6 | dhidhdhoo
# Processing Record 12 of Set 6 | chachapoyas
# Processing Record 13 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 6 | alvorada
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | riosucio
# Processing Record 17 of Set 6 | vardo
# Processing Record 18 of Set 6 | redmond
# Processing Record 19 of Set 6 | yellowknife
# Processing Record 20 of Set 6 | margate
# Processing Record 21 of Set 6 | faanui
# Processing Record 22 of Set 6 | plouzane
# Processing Record 23 of Set 6 | college
# Processing Record 24 of Set 6 | verkhnyaya inta
# Processing Record 25 of Set 6 | touros
# Processing Record 26 of Set 6 | djenne
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | maraba
# Processing Record 29 of Set 6 | klaksvik
# Processing Record 30 of Set 6 | adrar
# Processing Record 31 of Set 6 | muros
# Processing Record 32 of Set 6 | tasiilaq
# Processing Record 33 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 6 | saint pete beach
# Processing Record 35 of Set 6 | vytegra
# Processing Record 36 of Set 6 | taoudenni
# Processing Record 37 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 6 | port blair
# Processing Record 39 of Set 6 | hollola
# Processing Record 40 of Set 6 | farmington
# Processing Record 41 of Set 6 | boyle
# Processing Record 42 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 6 | san carlos de bariloche
# Processing Record 44 of Set 6 | chapleau
# Processing Record 45 of Set 6 | porto novo
# Processing Record 46 of Set 6 | kalemie
# Processing Record 47 of Set 6 | wolbrom
# Processing Record 48 of Set 6 | haapu
# City not found. Skipping...
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | bolshoye nagatkino
# Processing Record 1 of Set 7 | norman wells
# Processing Record 2 of Set 7 | newton
# Processing Record 3 of Set 7 | serafimovskiy
# Processing Record 4 of Set 7 | abashiri
# Processing Record 5 of Set 7 | solnechnyy
# Processing Record 6 of Set 7 | limbuhan
# Processing Record 7 of Set 7 | langenhagen
# Processing Record 8 of Set 7 | manzhouli
# Processing Record 9 of Set 7 | boyolangu
# Processing Record 10 of Set 7 | gari
# Processing Record 11 of Set 7 | bollnas
# Processing Record 12 of Set 7 | mandera
# Processing Record 13 of Set 7 | sur
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | fortuna
# Processing Record 16 of Set 7 | allanridge
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | padang
# Processing Record 19 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 7 | nizhniy ingash
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | grand baie
# Processing Record 23 of Set 7 | tuatapere
# Processing Record 24 of Set 7 | cairns
# Processing Record 25 of Set 7 | dafeng
# Processing Record 26 of Set 7 | port-cartier
# Processing Record 27 of Set 7 | lugovskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | pudozh
# Processing Record 30 of Set 7 | santa ana
# Processing Record 31 of Set 7 | rio grande
# Processing Record 32 of Set 7 | shuangcheng
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | sangin
# Processing Record 35 of Set 7 | westport
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | alexandria
# Processing Record 38 of Set 7 | merauke
# Processing Record 39 of Set 7 | naze
# Processing Record 40 of Set 7 | havre-saint-pierre
# Processing Record 41 of Set 7 | bartica
# Processing Record 42 of Set 7 | svarstad
# Processing Record 43 of Set 7 | bilma
# Processing Record 44 of Set 7 | noyabrsk
# Processing Record 45 of Set 7 | nioro
# Processing Record 46 of Set 7 | naryan-mar
# Processing Record 47 of Set 7 | chibombo
# Processing Record 48 of Set 7 | morondava
# Processing Record 49 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | alta
# Processing Record 2 of Set 8 | lethem
# Processing Record 3 of Set 8 | northam
# Processing Record 4 of Set 8 | bagdarin
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | deputatskiy
# Processing Record 7 of Set 8 | cayenne
# Processing Record 8 of Set 8 | inyonga
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | gamba
# Processing Record 12 of Set 8 | poum
# Processing Record 13 of Set 8 | bambous virieux
# Processing Record 14 of Set 8 | galle
# Processing Record 15 of Set 8 | zarechnyy
# Processing Record 16 of Set 8 | severo-yeniseyskiy
# Processing Record 17 of Set 8 | kysyl-syr
# Processing Record 18 of Set 8 | ulladulla
# Processing Record 19 of Set 8 | fort nelson
# Processing Record 20 of Set 8 | kedrovyy
# Processing Record 21 of Set 8 | lovozero
# Processing Record 22 of Set 8 | salalah
# Processing Record 23 of Set 8 | pingliang
# Processing Record 24 of Set 8 | jatai
# Processing Record 25 of Set 8 | high level
# Processing Record 26 of Set 8 | ketchikan
# Processing Record 27 of Set 8 | vicuna
# Processing Record 28 of Set 8 | cortez
# Processing Record 29 of Set 8 | khash
# Processing Record 30 of Set 8 | iqaluit
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | bure
# Processing Record 33 of Set 8 | shenjiamen
# Processing Record 34 of Set 8 | sechura
# Processing Record 35 of Set 8 | koster
# Processing Record 36 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 8 | varberg
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | acajutla
# Processing Record 40 of Set 8 | sibolga
# Processing Record 41 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 8 | pochutla
# Processing Record 43 of Set 8 | ternate
# Processing Record 44 of Set 8 | atagay
# Processing Record 45 of Set 8 | koslan
# Processing Record 46 of Set 8 | jalu
# Processing Record 47 of Set 8 | wuwei
# Processing Record 48 of Set 8 | bethel
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | mamou
# Processing Record 1 of Set 9 | nexo
# Processing Record 2 of Set 9 | curup
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | eureka
# Processing Record 5 of Set 9 | trelew
# Processing Record 6 of Set 9 | mayor pablo lagerenza
# Processing Record 7 of Set 9 | auxerre
# Processing Record 8 of Set 9 | namie
# Processing Record 9 of Set 9 | alvik
# Processing Record 10 of Set 9 | kondagaon
# Processing Record 11 of Set 9 | tuy hoa
# Processing Record 12 of Set 9 | nemuro
# Processing Record 13 of Set 9 | port augusta
# Processing Record 14 of Set 9 | chegutu
# Processing Record 15 of Set 9 | dudinka
# Processing Record 16 of Set 9 | edmond
# Processing Record 17 of Set 9 | paris
# Processing Record 18 of Set 9 | anori
# Processing Record 19 of Set 9 | constitucion
# Processing Record 20 of Set 9 | san rafael
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | strezhevoy
# Processing Record 24 of Set 9 | krasnogorskiy
# Processing Record 25 of Set 9 | rognan
# Processing Record 26 of Set 9 | basco
# Processing Record 27 of Set 9 | lufilufi
# Processing Record 28 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 9 | porto velho
# Processing Record 30 of Set 9 | scarborough
# Processing Record 31 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 9 | bintulu
# Processing Record 33 of Set 9 | praia da vitoria
# Processing Record 34 of Set 9 | yeppoon
# Processing Record 35 of Set 9 | tshela
# Processing Record 36 of Set 9 | caruray
# Processing Record 37 of Set 9 | hervey bay
# Processing Record 38 of Set 9 | severodvinsk
# Processing Record 39 of Set 9 | santa helena de goias
# Processing Record 40 of Set 9 | rovaniemi
# Processing Record 41 of Set 9 | bandrele
# Processing Record 42 of Set 9 | dingle
# Processing Record 43 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 9 | trinidad
# Processing Record 45 of Set 9 | sorland
# Processing Record 46 of Set 9 | sag
# Processing Record 47 of Set 9 | nome
# Processing Record 48 of Set 9 | mount isa
# Processing Record 49 of Set 9 | gat
# Processing Record 50 of Set 9 | siyabuswa
# Processing Record 1 of Set 10 | yarada
# Processing Record 2 of Set 10 | challapata
# Processing Record 3 of Set 10 | maarianhamina
# Processing Record 4 of Set 10 | kupang
# Processing Record 5 of Set 10 | itupiranga
# Processing Record 6 of Set 10 | yola
# Processing Record 7 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 8 of Set 10 | el prat de llobregat
# Processing Record 9 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 10 of Set 10 | stoughton
# Processing Record 11 of Set 10 | le port
# Processing Record 12 of Set 10 | chapais
# Processing Record 13 of Set 10 | banda aceh
# Processing Record 14 of Set 10 | batticaloa
# Processing Record 15 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 10 | miyako
# Processing Record 17 of Set 10 | kuybyshevo
# Processing Record 18 of Set 10 | sandwick
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | radhan
# Processing Record 21 of Set 10 | bay-khaak
# Processing Record 22 of Set 10 | kendari
# Processing Record 23 of Set 10 | puerto escondido
# Processing Record 24 of Set 10 | nevsehir
# Processing Record 25 of Set 10 | vryburg
# Processing Record 26 of Set 10 | roebourne
# Processing Record 27 of Set 10 | napanee
# Processing Record 28 of Set 10 | gizo
# Processing Record 29 of Set 10 | tilichiki
# Processing Record 30 of Set 10 | dhaulpur
# Processing Record 31 of Set 10 | egvekinot
# Processing Record 32 of Set 10 | scottsbluff
# Processing Record 33 of Set 10 | birjand
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | vila
# Processing Record 36 of Set 10 | bend
# Processing Record 37 of Set 10 | makakilo city
# Processing Record 38 of Set 10 | bonfim
# Processing Record 39 of Set 10 | katsuura
# Processing Record 40 of Set 10 | kihei
# Processing Record 41 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 10 | garowe
# Processing Record 43 of Set 10 | tabatinga
# Processing Record 44 of Set 10 | kutum
# Processing Record 45 of Set 10 | saint-georges
# Processing Record 46 of Set 10 | manitouwadge
# Processing Record 47 of Set 10 | clonakilty
# Processing Record 48 of Set 10 | lompoc
# Processing Record 49 of Set 10 | igarka
# Processing Record 50 of Set 10 | la ronge
# Processing Record 1 of Set 11 | dunedin
# Processing Record 2 of Set 11 | skjervoy
# Processing Record 3 of Set 11 | cape canaveral
# Processing Record 4 of Set 11 | oktyabrskoye
# Processing Record 5 of Set 11 | vanersborg
# Processing Record 6 of Set 11 | yaransk
# Processing Record 7 of Set 11 | scunthorpe
# Processing Record 8 of Set 11 | shwebo
# Processing Record 9 of Set 11 | mitsamiouli
# Processing Record 10 of Set 11 | udachnyy
# Processing Record 11 of Set 11 | alice springs
# Processing Record 12 of Set 11 | kamenka
# Processing Record 13 of Set 11 | bandar-e anzali
# Processing Record 14 of Set 11 | ardakan
# Processing Record 15 of Set 11 | praia
# Processing Record 16 of Set 11 | weston
# Processing Record 17 of Set 11 | luwuk
# Processing Record 18 of Set 11 | lorengau
# Processing Record 19 of Set 11 | esso
# Processing Record 20 of Set 11 | kavaratti
# Processing Record 21 of Set 11 | nadym
# Processing Record 22 of Set 11 | guane
# Processing Record 23 of Set 11 | takoradi
# Processing Record 24 of Set 11 | inhambane
# Processing Record 25 of Set 11 | angoram
# Processing Record 26 of Set 11 | kingman
# Processing Record 27 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | colares
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | ayr
# Processing Record 31 of Set 11 | chotila
# Processing Record 32 of Set 11 | awbari
# Processing Record 33 of Set 11 | hanzhong
# Processing Record 34 of Set 11 | wajid
# Processing Record 35 of Set 11 | daytona beach
# Processing Record 36 of Set 11 | mosquera
# Processing Record 37 of Set 11 | dayong
# Processing Record 38 of Set 11 | rantepao
# Processing Record 39 of Set 11 | horasan
# Processing Record 40 of Set 11 | coquimbo
# Processing Record 41 of Set 11 | marica
# Processing Record 42 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 11 | patiya
# Processing Record 44 of Set 11 | palia kalan
# Processing Record 45 of Set 11 | matara
# Processing Record 46 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 11 | dukat
# Processing Record 48 of Set 11 | eitorf
# Processing Record 49 of Set 11 | hamilton
# Processing Record 50 of Set 11 | serenje
# Processing Record 1 of Set 12 | saint-joseph
# Processing Record 2 of Set 12 | yulara
# Processing Record 3 of Set 12 | khagrachari
# City not found. Skipping...
# Processing Record 4 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 12 | lingao
# Processing Record 6 of Set 12 | colesberg
# Processing Record 7 of Set 12 | novyye gorki
# Processing Record 8 of Set 12 | mikhaylovka
# Processing Record 9 of Set 12 | dolores
# Processing Record 10 of Set 12 | ardesen
# Processing Record 11 of Set 12 | caibarien
# Processing Record 12 of Set 12 | port pirie
# Processing Record 13 of Set 12 | luanda
# Processing Record 14 of Set 12 | luquillo
# Processing Record 15 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 16 of Set 12 | beterou
# Processing Record 17 of Set 12 | nicoya
# Processing Record 18 of Set 12 | preobrazheniye
# Processing Record 19 of Set 12 | olean
# Processing Record 20 of Set 12 | ivanava
# Processing Record 21 of Set 12 | bar harbor
# Processing Record 22 of Set 12 | sal rei
# Processing Record 23 of Set 12 | khorixas
# Processing Record 24 of Set 12 | husavik
# Processing Record 25 of Set 12 | litovko
# Processing Record 26 of Set 12 | kathmandu
# Processing Record 27 of Set 12 | caravelas
# Processing Record 28 of Set 12 | likasi
# Processing Record 29 of Set 12 | xuddur
# Processing Record 30 of Set 12 | blackwater
# Processing Record 31 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 32 of Set 12 | bosobolo
# Processing Record 33 of Set 12 | boshan
# Processing Record 34 of Set 12 | artesia
# Processing Record 35 of Set 12 | pontypool
# Processing Record 36 of Set 12 | buraydah
# Processing Record 37 of Set 12 | najran
# Processing Record 38 of Set 12 | edd
# Processing Record 39 of Set 12 | acapulco
# Processing Record 40 of Set 12 | belawan
# Processing Record 41 of Set 12 | raymond
# Processing Record 42 of Set 12 | maragogi
# Processing Record 43 of Set 12 | bonavista
# Processing Record 44 of Set 12 | olga
# Processing Record 45 of Set 12 | paranaiba
# Processing Record 46 of Set 12 | prince rupert
# Processing Record 47 of Set 12 | viedma
# Processing Record 48 of Set 12 | asau
# Processing Record 49 of Set 12 | bereda
# Processing Record 50 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | manggar
# Processing Record 2 of Set 13 | hofn
# Processing Record 3 of Set 13 | prieska
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | tallahassee
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | bishop auckland
# Processing Record 8 of Set 13 | along
# Processing Record 9 of Set 13 | parainen
# Processing Record 10 of Set 13 | saint anthony
# Processing Record 11 of Set 13 | hede
# Processing Record 12 of Set 13 | bela vista
# Processing Record 13 of Set 13 | pundaguitan
# Processing Record 14 of Set 13 | cheyenne
# Processing Record 15 of Set 13 | nambucca heads
# Processing Record 16 of Set 13 | russellville
# Processing Record 17 of Set 13 | road town
# Processing Record 18 of Set 13 | sapozhok
# Processing Record 19 of Set 13 | lonevag
# Processing Record 20 of Set 13 | frome
# Processing Record 21 of Set 13 | price
# Processing Record 22 of Set 13 | promyshlennovskiy
# Processing Record 23 of Set 13 | kununurra
# Processing Record 24 of Set 13 | grand-lahou
# Processing Record 25 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 13 | changji
# Processing Record 27 of Set 13 | tokur
# Processing Record 28 of Set 13 | belem de sao francisco
# Processing Record 29 of Set 13 | kenda
# Processing Record 30 of Set 13 | yatou
# Processing Record 31 of Set 13 | beringovskiy
# Processing Record 32 of Set 13 | altay
# Processing Record 33 of Set 13 | elesbao veloso
# Processing Record 34 of Set 13 | castle bruce
# Processing Record 35 of Set 13 | seoul
# Processing Record 36 of Set 13 | lagos
# Processing Record 37 of Set 13 | kinsale
# Processing Record 38 of Set 13 | tezu
# Processing Record 39 of Set 13 | aksha
# Processing Record 40 of Set 13 | portree
# Processing Record 41 of Set 13 | flinders
# Processing Record 42 of Set 13 | madona
# Processing Record 43 of Set 13 | lao cai
# Processing Record 44 of Set 13 | vrbove
# Processing Record 45 of Set 13 | mattru
# Processing Record 46 of Set 13 | manyana
# Processing Record 47 of Set 13 | martapura
# Processing Record 48 of Set 13 | zhangye
# Processing Record 49 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 13 | tombouctou
# Processing Record 1 of Set 14 | santa maria
# Processing Record 2 of Set 14 | bisira
# Processing Record 3 of Set 14 | buluang
# Processing Record 4 of Set 14 | kashi
# Processing Record 5 of Set 14 | yusva
# City not found. Skipping...
# Processing Record 6 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 14 | glowno
# Processing Record 8 of Set 14 | rabo de peixe
# Processing Record 9 of Set 14 | meligalas
# Processing Record 10 of Set 14 | shafranovo
# Processing Record 11 of Set 14 | bayan
# Processing Record 12 of Set 14 | korla
# Processing Record 13 of Set 14 | kasongo-lunda
# Processing Record 14 of Set 14 | at-bashi
# Processing Record 15 of Set 14 | manta
# Processing Record 16 of Set 14 | richards bay
# Processing Record 17 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 14 | camara de lobos
# Processing Record 19 of Set 14 | yantal
# Processing Record 20 of Set 14 | port hardy
# Processing Record 21 of Set 14 | manokwari
# Processing Record 22 of Set 14 | dodge city
# Processing Record 23 of Set 14 | ust-tsilma
# Processing Record 24 of Set 14 | hilsa
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | nosy varika
# Processing Record 27 of Set 14 | grafton
# Processing Record 28 of Set 14 | itacoatiara
# Processing Record 29 of Set 14 | khorinsk
# Processing Record 30 of Set 14 | ankpa
# Processing Record 31 of Set 14 | rincon de la victoria
# Processing Record 32 of Set 14 | qaqortoq
# Processing Record 33 of Set 14 | fare
# Processing Record 34 of Set 14 | puka
# Processing Record 35 of Set 14 | aquiraz
# Processing Record 36 of Set 14 | sabya
# Processing Record 37 of Set 14 | mailsi
# Processing Record 38 of Set 14 | kholm-zhirkovskiy
# Processing Record 39 of Set 14 | victor harbor
# Processing Record 40 of Set 14 | shirokiy
# Processing Record 41 of Set 14 | anito
# Processing Record 42 of Set 14 | la rioja
# Processing Record 43 of Set 14 | liepaja
# Processing Record 44 of Set 14 | shache
# Processing Record 45 of Set 14 | cap malheureux
# Processing Record 46 of Set 14 | dwarka
# Processing Record 47 of Set 14 | vega de alatorre
# Processing Record 48 of Set 14 | penzance
# Processing Record 49 of Set 14 | las vegas
# Processing Record 50 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 15 | vaitape
# Processing Record 2 of Set 15 | kon tum
# Processing Record 3 of Set 15 | kirando
# Processing Record 4 of Set 15 | boma
# Processing Record 5 of Set 15 | nouadhibou
# Processing Record 6 of Set 15 | kopavogur
# Processing Record 7 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 15 | danane
# Processing Record 10 of Set 15 | la paz
# Processing Record 11 of Set 15 | lata
# Processing Record 12 of Set 15 | canete
# Processing Record 13 of Set 15 | hambantota
# Processing Record 14 of Set 15 | oistins
# Processing Record 15 of Set 15 | tokonou
# Processing Record 16 of Set 15 | tutrakan
# Processing Record 17 of Set 15 | marsa matruh
# Processing Record 18 of Set 15 | pochinki
# Processing Record 19 of Set 15 | deer lake
# Processing Record 20 of Set 15 | antalaha
# Processing Record 21 of Set 15 | kidal
# Processing Record 22 of Set 15 | mareeba
# Processing Record 23 of Set 15 | rio gallegos
# Processing Record 24 of Set 15 | cururupu
# Processing Record 25 of Set 15 | totskoye
# Processing Record 26 of Set 15 | copiapo
# Processing Record 27 of Set 15 | wuchang
# Processing Record 28 of Set 15 | sasaram
# Processing Record 29 of Set 15 | pangai
# Processing Record 30 of Set 15 | pringsewu
# Processing Record 31 of Set 15 | labuhan
# Processing Record 32 of Set 15 | griffith
# Processing Record 33 of Set 15 | quchan
# Processing Record 34 of Set 15 | hun
# Processing Record 35 of Set 15 | gao
# Processing Record 36 of Set 15 | lavrentiya
# Processing Record 37 of Set 15 | horki
# Processing Record 38 of Set 15 | pokotylivka
# Processing Record 39 of Set 15 | portobelo
# Processing Record 40 of Set 15 | shaowu
# Processing Record 41 of Set 15 | totton
# Processing Record 42 of Set 15 | mandalgovi
# Processing Record 43 of Set 15 | peterhead
# Processing Record 44 of Set 15 | umm kaddadah
# Processing Record 45 of Set 15 | port lincoln
# Processing Record 46 of Set 15 | bolivar
# Processing Record 47 of Set 15 | channel-port aux basques
# Processing Record 48 of Set 15 | fos-sur-mer
# Processing Record 49 of Set 15 | amuntai
# Processing Record 50 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 1 of Set 16 | raga
# Processing Record 2 of Set 16 | bukama
# Processing Record 3 of Set 16 | mbandaka
# Processing Record 4 of Set 16 | atambua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Avarua      CK -21.2078 -159.7750     86.05        74
# 1         Upernavik      GL  72.7868  -56.1549     13.66        84
# 2            Atuona      PF  -9.8000 -139.0333     79.07        72
# 3  Vyshchetarasivka      UA  47.5685   34.8810     44.98        83
# 4       Tuktoyaktuk      CA  69.4541 -133.0374    -15.48        94
# 5       Port Alfred      ZA -33.5906   26.8910     65.17        76
# 6   Mnogovershinnyy      RU  53.9353  139.9242     21.27        62
# 7      Longyearbyen      SJ  78.2186   15.6401      6.64        61
# 8            Albany      US  42.6001  -73.9662     39.61        38
# 9    Port Elizabeth      ZA -33.9180   25.5701     64.31        74
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0          25        9.22    scattered clouds  2022-03-31 02:14:06
# 1          36        6.44    scattered clouds  2022-03-31 02:14:06
# 2          29       12.80    scattered clouds  2022-03-31 02:14:07
# 3         100       11.41     overcast clouds  2022-03-31 02:14:07
# 4         100        8.34     overcast clouds  2022-03-31 02:14:08
# 5         100        3.80     overcast clouds  2022-03-31 02:14:08
# 6           5        8.59           clear sky  2022-03-31 02:14:09
# 7           0        2.30           clear sky  2022-03-31 02:13:19
# 8         100        4.00     overcast clouds  2022-03-31 02:12:31
# 9         100        1.99     overcast clouds  2022-03-31 02:14:10

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
